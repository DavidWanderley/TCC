# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

pd.set_option("display.max_columns", 50)
pd.set_option("display.max_rows", 50)

# %%
arq = open(r'C:\Users\Wanderley\Source\Repos\TCC\DATA\dados-de-nascidos-vivos.csv', 'r')

# %%
df = {}

df = pd.read_csv(arq, sep=';', dtype='unicode')
display(df)
# Out:
#       ORIGEM CODESTAB CODMUNNASC LOCNASC IDADEMAE ESTCIVMAE ESCMAE CODOCUPMAE  \
# 0          1  7047428     230440       1       24         1      4     999992
# 1          1  2497654     230440       1       21         1      3     513205
# 2          1  2481286     230440       1       31         2      3     999992
# 3          1  2497654     230440       1       28         2      3     763015
# 4          1  2481286     230440       1       18         5      3     999992
# ...      ...      ...        ...     ...      ...       ...    ...        ...
# 40939      1  2651351     230440       1       43         2      4     763010
# 40940      1  2497654     230440       1       38         1      3     631010
# 40941      1  2651351     230440       1       25         5      3     354705
# 40942      1  2497654     230440       1       18         2      3     999992
# 40943      1  2497654     230440       1       25         2      3     999992
#
# ...

# %%
df.tail(5)
# Out:
#       ORIGEM CODESTAB CODMUNNASC LOCNASC IDADEMAE ESTCIVMAE ESCMAE CODOCUPMAE  \
# 40939      1  2651351     230440       1       43         2      4     763010
# 40940      1  2497654     230440       1       38         1      3     631010
# 40941      1  2651351     230440       1       25         5      3     354705
# 40942      1  2497654     230440       1       18         2      3     999992
# 40943      1  2497654     230440       1       25         2      3     999992
#
#       QTDFILVIVO QTDFILMORT CODMUNRES GESTACAO GRAVIDEZ PARTO CONSULTAS  \
# 40939         02         01    230440        5        1     2         4
# 40940         03         00    230440        5        1     2         2
# 40941         02        NaN    230370        5        1     1         4
# 40942         01         00    230440        5        1     2         2
# 40943         03         04    230440      NaN        1     2         1
#
# ...

# %%
PARTO = list(range(1,3))
PARTO
# Out:
# [1, 2]

# %%
fig = plt.figure(figsize=[20,20])
for i, p in zip(range(1,12), PARTO):
    fig.add_subplot(6, 2, i)
    sns.heatmap(df.isnull(), cbar = False);

# %%
parto_df = pd.concat([pd.DataFrame(df) for p in PARTO],
          ignore_index=True)

# %%
parto_df.shape
# Out:
# (81888, 60)

# %%
parto_df.drop(['CODANOMAL', 'DTRECORIGA', 'IDADEPAI', 'DTULTMENST', 'RACACOR', 'SERIESCMAE', 'RACACORMAE', 'QTDPARTNOR', 'QTDFILVIVO', 'QTDGESTANT', 'QTDFILMORT'], axis = 1, inplace=True)

# %%
parto_df.sample(5)
# Out:
#       ORIGEM CODESTAB CODMUNNASC LOCNASC IDADEMAE ESTCIVMAE ESCMAE CODOCUPMAE  \
# 6536       1  2482339     230440       1       30         1      4     354705
# 34809      1  2479907     230440       1       27         2      5     241340
# 21437      1  9297502     230440       1       34         1      5     422105
# 50071      1  2499363     230440       1       32         1      3     513205
# 13464      1  3394514     230440       1       35         2      5     333115
#
#       CODMUNRES GESTACAO GRAVIDEZ PARTO CONSULTAS    DTNASC HORANASC SEXO  \
# 6536     230440        5        1     2         4  07032020     0031    2
# 34809    230220        5        1     2         4  16102020     1540    1
# 21437    230960        5        1     2         4  01072020     0930    1
# 50071    230440        4        1     2         3  17032020     1150    1
# 13464    230440        4        1     2         4  29042020     1934    1
#
# ...

# %%
sns.heatmap(parto_df.isnull(), cbar = False);

# %%
parto_df.shape
# Out:
# (81888, 49)

# %%
 parto_df.dropna(inplace=True)

# %%
sns.heatmap(parto_df.isnull(), cbar = False);

# %%
parto_df.shape
# Out:
# (40626, 49)

# %%
parto_df.describe()
# Out:
#        ORIGEM CODESTAB CODMUNNASC LOCNASC IDADEMAE ESTCIVMAE ESCMAE  \
# count   40626    40626      40626   40626    40626     40626  40626
# unique      1       18          1       2       40         6      6
# top         1  2481286     230440       1       25         1      4
# freq    40626     7950      40626   40602     2116     20136  25572
#
#        CODOCUPMAE CODMUNRES GESTACAO GRAVIDEZ  PARTO CONSULTAS    DTNASC  \
# count       40626     40626    40626    40626  40626     40626     40626
# unique        491       136        6        3      2         5       366
# top        999992    230440        5        1      2         4  22052020
# freq        20998     29800    33004    39430  26862     27006       188
#
#        HORANASC   SEXO APGAR1 APGAR5   PESO IDANOMAL DTCADASTRO NUMEROLOTE  \
# count     40626  40626  40626  40626  40626    40626      40626      40626
# unique     1439      3     12     12   1990        3        405         69
# ...

# %%
parto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40626 entries, 0 to 81886
# Data columns (total 49 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ORIGEM      40626 non-null  object
#  1   CODESTAB    40626 non-null  object
#  2   CODMUNNASC  40626 non-null  object
#  3   LOCNASC     40626 non-null  object
#  4   IDADEMAE    40626 non-null  object
#  5   ESTCIVMAE   40626 non-null  object
#  6   ESCMAE      40626 non-null  object
#  7   CODOCUPMAE  40626 non-null  object
#  8   CODMUNRES   40626 non-null  object
#  9   GESTACAO    40626 non-null  object
#  10  GRAVIDEZ    40626 non-null  object
#  11  PARTO       40626 non-null  object
#  12  CONSULTAS   40626 non-null  object
#  13  DTNASC      40626 non-null  object
#  14  HORANASC    40626 non-null  object
#  15  SEXO        40626 non-null  object
#  16  APGAR1      40626 non-null  object
#  17  APGAR5      40626 non-null  object
#  18  PESO        40626 non-null  object
# ...

# %%
parto_df.drop(['ORIGEM', 'CODMUNNASC', 'DTCADASTRO', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU'], axis = 1, inplace=True)

# %%
sns.heatmap(parto_df.isnull(), cbar = False);

# %%
parto_df.shape
# Out:
# (40626, 39)

# %%
parto_df = parto_df.astype('int')

# %%
parto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40626 entries, 0 to 81886
# Data columns (total 39 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CODESTAB    40626 non-null  int32
#  1   LOCNASC     40626 non-null  int32
#  2   IDADEMAE    40626 non-null  int32
#  3   ESTCIVMAE   40626 non-null  int32
#  4   ESCMAE      40626 non-null  int32
#  5   CODOCUPMAE  40626 non-null  int32
#  6   CODMUNRES   40626 non-null  int32
#  7   GESTACAO    40626 non-null  int32
#  8   GRAVIDEZ    40626 non-null  int32
#  9   PARTO       40626 non-null  int32
#  10  CONSULTAS   40626 non-null  int32
#  11  DTNASC      40626 non-null  int32
#  12  HORANASC    40626 non-null  int32
#  13  SEXO        40626 non-null  int32
#  14  APGAR1      40626 non-null  int32
#  15  APGAR5      40626 non-null  int32
#  16  PESO        40626 non-null  int32
#  17  IDANOMAL    40626 non-null  int32
#  18  ESCMAE2010  40626 non-null  int32
# ...

# %%
parto_df.hist(bins = 30, figsize=(10,5), color = 'b');

# %%
parto_df.hist(bins = 5)

# %% [markdown]
# 1 - remover colunas
# 2 - converter para inteiro
# 3 - plotar os histogramas
